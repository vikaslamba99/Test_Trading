# %%
import warnings
warnings.filterwarnings('ignore')

# %%
# %matplotlib inline

import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.feature_selection import mutual_info_classif

# %%
sns.set_style('whitegrid')
idx = pd.IndexSlice

# %%
with pd.HDFStore('/Volumes/My Book/Data_Analysis/Nasdaq/assets.h5') as store:
    data = store['engineered_features']

# %%
dummy_data = pd.get_dummies(data,
                            columns=['year','month', 'msize', 'age',  'sector'],
                            prefix=['year','month', 'msize', 'age', ''],
                            prefix_sep=['_', '_', '_', '_', ''])
dummy_data = dummy_data.rename(columns={c:c.replace('.0', '') for c in dummy_data.columns})
dummy_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 280610 entries, ('A', Timestamp('2001-01-31 00:00:00')) to ('ZUMZ', Timestamp('2018-02-28 00:00:00'))
# Data columns (total 87 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   return_1m               280610 non-null  float64
#  1   return_2m               280610 non-null  float64
#  2   return_3m               280610 non-null  float64
#  3   return_6m               280610 non-null  float64
#  4   return_9m               280610 non-null  float64
#  5   return_12m              280610 non-null  float64
#  6   Mkt-RF                  280610 non-null  float64
#  7   SMB                     280610 non-null  float64
#  8   HML                     280610 non-null  float64
#  9   RMW                     280610 non-null  float64
#  10  CMA                     280610 non-null  float64
#  11  momentum_2              280610 non-null  float64
#  12  momentum_3              280610 non-null  float64
#  13  momentum_6              280610 non-null  float64
#  14  momentum_9              280610 non-null  float64
#  15  momentum_12             280610 non-null  float64
#  16  momentum_3_12           280610 non-null  float64
#  17  return_1m_t-1           279179 non-null  float64
#  18  return_1m_t-2           277748 non-null  float64
#  19  return_1m_t-3           276317 non-null  float64
#  20  return_1m_t-4           274886 non-null  float64
#  21  return_1m_t-5           273455 non-null  float64
#  22  return_1m_t-6           272024 non-null  float64
#  23  target_1m               280610 non-null  float64
#  24  target_2m               279179 non-null  float64
#  25  target_3m               277748 non-null  float64
#  26  target_6m               273455 non-null  float64
#  27  target_12m              264869 non-null  float64
#  28  year_2001               280610 non-null  bool
#  29  year_2002               280610 non-null  bool
#  30  year_2003               280610 non-null  bool
#  31  year_2004               280610 non-null  bool
#  32  year_2005               280610 non-null  bool
#  33  year_2006               280610 non-null  bool
#  34  year_2007               280610 non-null  bool
#  35  year_2008               280610 non-null  bool
#  36  year_2009               280610 non-null  bool
#  37  year_2010               280610 non-null  bool
#  38  year_2011               280610 non-null  bool
#  39  year_2012               280610 non-null  bool
#  40  year_2013               280610 non-null  bool
#  41  year_2014               280610 non-null  bool
#  42  year_2015               280610 non-null  bool
#  43  year_2016               280610 non-null  bool
#  44  year_2017               280610 non-null  bool
#  45  year_2018               280610 non-null  bool
#  46  month_1                 280610 non-null  bool
#  47  month_2                 280610 non-null  bool
#  48  month_3                 280610 non-null  bool
#  49  month_4                 280610 non-null  bool
#  50  month_5                 280610 non-null  bool
#  51  month_6                 280610 non-null  bool
#  52  month_7                 280610 non-null  bool
#  53  month_8                 280610 non-null  bool
#  54  month_9                 280610 non-null  bool
#  55  month_10                280610 non-null  bool
#  56  month_11                280610 non-null  bool
#  57  month_12                280610 non-null  bool
#  58  msize_1                 280610 non-null  bool
#  59  msize_2                 280610 non-null  bool
#  60  msize_3                 280610 non-null  bool
#  61  msize_4                 280610 non-null  bool
#  62  msize_5                 280610 non-null  bool
#  63  msize_6                 280610 non-null  bool
#  64  msize_7                 280610 non-null  bool
#  65  msize_8                 280610 non-null  bool
#  66  msize_9                 280610 non-null  bool
#  67  msize_10                280610 non-null  bool
#  68  age_0                   280610 non-null  bool
#  69  age_1                   280610 non-null  bool
#  70  age_2                   280610 non-null  bool
#  71  age_3                   280610 non-null  bool
#  72  age_4                   280610 non-null  bool
#  73  age_5                   280610 non-null  bool
#  74  Basic Materials         280610 non-null  bool
#  75  Consumer Discretionary  280610 non-null  bool
#  76  Consumer Staples        280610 non-null  bool
#  77  Energy                  280610 non-null  bool
#  78  Finance                 280610 non-null  bool
#  79  Health Care             280610 non-null  bool
#  80  Industrials             280610 non-null  bool
#  81  Miscellaneous           280610 non-null  bool
#  82  Real Estate             280610 non-null  bool
#  83  Technology              280610 non-null  bool
#  84  Telecommunications      280610 non-null  bool
#  85  Unknown                 280610 non-null  bool
#  86  Utilities               280610 non-null  bool
# dtypes: bool(59), float64(28)
# memory usage: 76.9+ MB

# %%
# Original Data
target_labels = [f'target_{i}m' for i in [1,2,3,6,12]]
targets = data.dropna().loc[:, target_labels]

features = data.dropna().drop(target_labels, axis=1)
features.sector = pd.factorize(features.sector)[0]

cat_cols = ['year', 'month', 'msize', 'age', 'sector']
discrete_features = [features.columns.get_loc(c) for c in cat_cols]

# %%
mutual_info = pd.DataFrame()
for label in target_labels:
    mi = mutual_info_classif(X=features, 
                             y=(targets[label]> 0).astype(int),
                             discrete_features=discrete_features,
                             random_state=42
                            )
    mutual_info[label] = pd.Series(mi, index=features.columns)

# %%
mutual_info.sum()
# Out:
# target_1m     0.042465
# target_2m     0.065256
# target_3m     0.095303
# target_6m     0.143797
# target_12m    0.215305
# dtype: float64

# %%
fig, ax= plt.subplots(figsize=(15, 4))
sns.heatmap(mutual_info.div(mutual_info.sum()).T, ax=ax, cmap='Blues');

# %%
# Dummy Data
target_labels = [f'target_{i}m' for i in [1, 2, 3, 6, 12]]
dummy_targets = dummy_data.dropna().loc[:, target_labels]

dummy_features = dummy_data.dropna().drop(target_labels, axis=1)
cat_cols = [c for c in dummy_features.columns if c not in features.columns]
discrete_features = [dummy_features.columns.get_loc(c) for c in cat_cols]

# %%
mutual_info_dummies = pd.DataFrame()
for label in target_labels:
    mi = mutual_info_classif(X=dummy_features, 
                             y=(dummy_targets[label]> 0).astype(int),
                             discrete_features=discrete_features,
                             random_state=42
                            )    
    mutual_info_dummies[label] = pd.Series(mi, index=dummy_features.columns)

# %%
fig, ax= plt.subplots(figsize=(4, 20))
sns.heatmap(mutual_info_dummies.div(mutual_info_dummies.sum()), ax=ax, cmap='Blues');
